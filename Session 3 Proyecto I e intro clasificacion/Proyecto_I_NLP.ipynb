# %% [markdown]
# # Procesamiento de Lenguaje Natural
#
#
# **Pablo Martínez Olmos**
#
# Departamento de Teoría de la Señal y Comunicaciones
#
# **Universidad Carlos III de Madrid**
#
# <img src='http://www.tsc.uc3m.es/~emipar/BBVA/INTRO/img/logo_uc3m_foot.jpg' width=400 />

# %% [markdown]
# # Proyecto I: agrupación reclamaciones en una base de datos de clientes de productos/servicios financieros

# %% [markdown]
# En este proyecto, utilizaremos la siguiente [base de datos](https://catalog.data.gov/dataset/consumer-complaint-database) publicada por el *Bureau of Consumer Financial Protection* (BCFP), agencial federal de EEUU:
#
# > The Consumer Complaint Database is a collection of complaints about consumer financial products and services that we sent to  companies for response. Complaints are published after the company responds, confirming a commercial relationship with the  consumer, or after 15 days, whichever comes first. Complaints referred to other regulators, such as complaints about depository institutions with less than $10 billion in assets, are not published in the Consumer Complaint Database.
#
# Podemos cargar la base de datos completa del siguiente modo:
#
# ```python
# df = pd.read_csv('https://files.consumerfinance.gov/ccdb/complaints.csv.zip', compression='zip', sep=',')
# ```
#
# Pero es bastante pesada (1.2 Gb). Vamos a cargar un pequeño extracto de la misma, con unos 20.000 registros ...

# %%
import pandas as pd

df = pd.read_csv('http://www.tsc.uc3m.es/~olmos/BBVA/complaints_extracto.csv', sep=',')

# %%
df.head(10)
# Out:
#    Unnamed: 0 Date received  \
# 0     1050152    2018-02-11
# 1      138991    2019-04-18
# 2     1128029    2014-03-01
# 3       54959    2019-07-08
# 4     2007823    2018-11-18
# 5      671104    2020-12-18
# 6      671377    2021-02-08
# 7      502772    2020-08-06
# 8        6661    2019-03-26
# 9     1552571    2014-12-13
#
#                                              Product  \
# 0  Credit reporting, credit repair services, or o...
# 1  Credit reporting, credit repair services, or o...
# 2                                           Mortgage
# 3                                    Debt collection
# 4  Credit reporting, credit repair services, or o...
# 5                                    Debt collection
# 6                        Checking or savings account
# 7  Credit reporting, credit repair services, or o...
# 8  Credit reporting, credit repair services, or o...
# 9                                   Credit reporting
#
#                               Sub-product  \
# 0                        Credit reporting
# 1                        Credit reporting
# 2  Conventional adjustable mortgage (ARM)
# 3                        Credit card debt
# 4                        Credit reporting
# 5                        Credit card debt
# 6                        Checking account
# 7                        Credit reporting
# 8                        Credit reporting
# 9                                     NaN
#
#                                                Issue  \
# 0  Problem with a credit reporting company's inve...
# 1               Incorrect information on your report
# 2           Loan modification,collection,foreclosure
# 3                              Communication tactics
# 4               Incorrect information on your report
# 5                  Attempts to collect debt not owed
# 6                                Managing an account
# 7               Incorrect information on your report
# 8               Incorrect information on your report
# 9           Unable to get credit report/credit score
#
#                                            Sub-issue  \
# 0  Their investigation did not fix an error on yo...
# 1                           Account status incorrect
# 2                                                NaN
# 3                         Frequent or repeated calls
# 4                      Account information incorrect
# 5                  Debt was result of identity theft
# 6                  Problem using a debit or ATM card
# 7                Information belongs to someone else
# 8       Old information reappears or never goes away
# 9              Problem getting my free annual report
#
#                         Consumer complaint narrative  \
# 0  I disputed with this company back in XXXX the ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  XXXX Details Account # XXXX A payment was sent...
# 5                                                NaN
# 6  This is more of a general complaint because it...
# 7  MY WIFE AND I HAVE BEEN A VICTIM OF IDENTITY T...
# 8                                                NaN
# 9                                                NaN
#
#                              Company public response  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Company has responded to the consumer and the ...
# 5  Company has responded to the consumer and the ...
# 6  Company has responded to the consumer and the ...
# 7  Company has responded to the consumer and the ...
# 8  Company has responded to the consumer and the ...
# 9                                                NaN
#
#                                   Company State ZIP code            Tags  \
# 0                           EQUIFAX, INC.    MI    482XX             NaN
# 1                           EQUIFAX, INC.    PR    00987             NaN
# 2             Ocwen Financial Corporation    CA    91601             NaN
# 3             Radius Global Solutions LLC    FL    33756             NaN
# 4     Experian Information Solutions Inc.    WI      NaN             NaN
# 5  TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    75904             NaN
# 6   BANK OF AMERICA, NATIONAL ASSOCIATION    PA    194XX             NaN
# 7     Experian Information Solutions Inc.    AR    721XX             NaN
# 8     Experian Information Solutions Inc.    ID    832XX             NaN
# 9  TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    77005  Older American
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0           Consent provided           Web           2018-02-11
# 1       Consent not provided           Web           2019-04-18
# 2                        NaN           Web           2014-02-28
# 3       Consent not provided           Web           2019-07-08
# 4           Consent provided           Web           2018-11-18
# 5       Consent not provided           Web           2020-12-18
# 6           Consent provided           Web           2021-02-08
# 7           Consent provided           Web           2020-08-06
# 8       Consent not provided           Web           2019-03-26
# 9                        NaN           Web           2014-12-16
#
#       Company response to consumer Timely response? Consumer disputed?  \
# 0          Closed with explanation              Yes                NaN
# 1  Closed with non-monetary relief              Yes                NaN
# 2          Closed with explanation              Yes                 No
# 3          Closed with explanation              Yes                NaN
# 4  Closed with non-monetary relief              Yes                NaN
# 5          Closed with explanation              Yes                NaN
# 6      Closed with monetary relief              Yes                NaN
# 7          Closed with explanation              Yes                NaN
# 8          Closed with explanation              Yes                NaN
# 9  Closed with non-monetary relief              Yes                 No
#
#    Complaint ID
# 0       2811182
# 1       3216620
# 2        738615
# 3       3298990
# 4       3077718
# 5       4019919
# 6       4124936
# 7       3782734
# 8       3191684
# 9       1155672

# %% [markdown]
# Vamos a centrarnos en el campo `Consumer complaint narrative`:

# %%
complaints = list(df['Consumer complaint narrative'])

# Complaints es una lista con las quejas de los usuarios

complaints[0]
# Out:
# 'I disputed with this company back in XXXX the company is XXXX. They didnt send me any method of verification stating a original signed contract with my signature because according to Section 609 of the FCRA it has to be proof of a original signed contract with my signature. This company just continues to report this on my credit report and being that XXXX has so many names and addresses on my file I didnt sign up for this.Please reach out to this company XXXX to investigate.'

# %% [markdown]
# Lo primero, vamos a hacernos una idea de la longitud del textos para los distintos registros.
#
# > **Ejercicio** Dibuje el histograma del número de palabras por entrada del campo `Consumer complaint narrative`.

# %%
# YOUR CODE HERE

# %% [markdown]
# Habrás podido comprobar como los textos son de longitud muy variable. Este campo puede llegar a ser muy largo, de tal manera que la representación mediante TF-IDF o promedio word2vec puede ser perder capacidad discriminativa. Vamos a implementar una función para resumir cada documento con sus 3 oraciones más significativas.
#
# > **Ejercicio**: Cree una función que, dado un texto en formato *string*, devuelva un resumen con las $I=3$ oraciones más significativas utilizando TextRank. El formato del texto resumido debe ser un único *string* con la concatenación de $I$ oraciones encontradas (**Nota: concatene las oraciones ORIGINALES, sin normalizar**).

# %%
# YOUR CODE HERE

# %% [markdown]
# > **Ejercicio:** Genere un corpus de documentos resumidos, en un formato lista de *strings*.

# %%
# YOUR CODE HERE

# %% [markdown]
# > **Ejercicio**: Normalice el corpus resumido y genere la codificación TF-IDF de todos los documentos.

# %%
# YOUR CODE HERE

# %% [markdown]
# >**Ejercicio**: Finalmente, haga un agrupamiento de las quejas usando K-means y distancia coseno. Utilice $K=5$ grupos. Imprima algunos documentos de cada grupo y discuta los resultados.

# %%
# YOUR CODE HERE
